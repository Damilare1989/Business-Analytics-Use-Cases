# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
fr = pd.read_csv('Fundraising.csv')

# %%
fr.head()
# Out:
#    Row Id  Row Id.  zipconvert_2  zipconvert_3  zipconvert_4  zipconvert_5  \
# 0       1       17             0             1             0             0
# 1       2       25             1             0             0             0
# 2       3       29             0             0             0             1
# 3       4       38             0             0             0             1
# 4       5       40             0             1             0             0
#
#    homeowner dummy  NUMCHLD  INCOME  gender dummy  ...  IC15  NUMPROM  \
# 0                1        1       5             1  ...     1       74
# 1                1        1       1             0  ...     4       46
# 2                0        2       5             1  ...    13       32
# 3                1        1       3             0  ...     4       94
# 4                1        1       4             0  ...     7       20
#
#    RAMNTALL  MAXRAMNT  LASTGIFT  totalmonths  TIMELAG   AVGGIFT  TARGET_B  \
# ...

# %%
fr.shape
# Out:
# (3120, 24)

# %%
fr.iloc[0]
# Out:
# Row Id                1.000000
# Row Id.              17.000000
# zipconvert_2          0.000000
# zipconvert_3          1.000000
# zipconvert_4          0.000000
# zipconvert_5          0.000000
# homeowner dummy       1.000000
# NUMCHLD               1.000000
# INCOME                5.000000
# gender dummy          1.000000
# WEALTH                9.000000
# HV                 1399.000000
# Icmed               637.000000
# Icavg               703.000000
# IC15                  1.000000
# NUMPROM              74.000000
# RAMNTALL            102.000000
# MAXRAMNT              6.000000
# LASTGIFT              5.000000
# totalmonths          29.000000
# TIMELAG               3.000000
# AVGGIFT               4.857143
# TARGET_B              1.000000
# TARGET_D              5.000000
# Name: 0, dtype: float64
