# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
tk = pd.read_csv('Tayko.csv')

# %%
tk.head()
# Out:
#    sequence_number  US  source_a  source_c  source_b  source_d  source_e  \
# 0                1   1         0         0         1         0         0
# 1                2   1         0         0         0         0         1
# 2                3   1         0         0         0         0         0
# 3                4   1         0         1         0         0         0
# 4                5   1         0         1         0         0         0
#
#    source_m  source_o  source_h  ...  source_x  source_w  Freq  \
# 0         0         0         0  ...         0         0     2
# 1         0         0         0  ...         0         0     0
# 2         0         0         0  ...         0         0     2
# 3         0         0         0  ...         0         0     1
# 4         0         0         0  ...         0         0     1
#
#    last_update_days_ago  1st_update_days_ago  Web order  Gender=male  \
# 0                  3662                 3662          1            0
# ...

# %%
tk.shape
# Out:
# (2000, 25)

# %%
tk.iloc[0]
# Out:
# sequence_number            1
# US                         1
# source_a                   0
# source_c                   0
# source_b                   1
# source_d                   0
# source_e                   0
# source_m                   0
# source_o                   0
# source_h                   0
# source_r                   0
# source_s                   0
# source_t                   0
# source_u                   0
# source_p                   0
# source_x                   0
# source_w                   0
# Freq                       2
# last_update_days_ago    3662
# 1st_update_days_ago     3662
# Web order                  1
# Gender=male                0
# Address_is_res             1
# Purchase                   1
# Spending                 128
# Name: 0, dtype: int64
